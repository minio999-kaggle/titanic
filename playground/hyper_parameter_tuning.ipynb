# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# ## Timer

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %% [markdown]
# ## setup from previous notebook

# %%
TRAIN_PATH = '../data/train.csv'
TEST_PATH = '../data/test.csv'
N_SPLITS = 5
RANDOM_STATE = 42


def extracting_title_age_imputing(data_df, train_df, test_df):
    '''
    Function to extract title and impute age

    Parameters:
        dataframe (pandas.DataFrame): DataFrame on which to operate
        dataframe (pandas.DataFrame): DataFrame on which to train
        dataframe (pandas.DataFrame): DataFrame on which to test
    '''
    data_df['Title'] = data_df['Name']

    for name_string in data_df['Name']:
        data_df['Title'] = data_df['Name'].str.extract('([A-Za-z]+)\.', expand=True)

    mapping = {'Mlle': 'Miss', 'Major': 'Mr', 'Col':
                'Mr', 'Sir': 'Mr', 'Don': 'Mr', 'Mme': 'Miss',
                'Jonkheer': 'Mr', 'Lady': 'Mrs', 'Capt':
                'Mr', 'Countess': 'Mrs', 'Ms': 'Miss', 'Dona': 'Mrs'}
    data_df.replace({'Title': mapping}, inplace=True)

    titles = ['Dr', 'Master', 'Miss', 'Mr', 'Mrs', 'Rev']
    for title in titles:
        age_to_impute = data_df.groupby('Title')['Age'].median()[titles.index(title)]
        data_df.loc[(data_df['Age'].isnull()) & (data_df['Title'] == title), 'Age'] = age_to_impute

    train_df['Age'] = data_df['Age'][:891]
    test_df['Age'] = data_df['Age'][891:]
    data_df.drop('Title', axis = 1, inplace = True)

def family_size(data_df, train_df, test_df):
    '''
    Function to combine Parch and Sibsp columns to get family size on board

    Parameters:
        dataframe (pandas.DataFrame): DataFrame on which to operate
        dataframe (pandas.DataFrame): DataFrame on which to train
        dataframe (pandas.DataFrame): DataFrame on which to test
    '''
    data_df['Family_Size'] = data_df['Parch'] + data_df['SibSp']
    train_df['Family_Size'] = data_df['Family_Size'][:891]
    test_df['Family_Size'] = data_df['Family_Size'][891:]

def spliting_name(data_df):
    '''
    Function to split name column to name and last name

    Parameters:
        dataframe (pandas.DataFrame): DataFrame on which to operate
    '''
    data_df['Last_Name'] = data_df['Name'].apply(lambda x: str.split(x, ",")[0])
    
def imputing_fare(data_df):
    '''
    Function to impute fare column

    Parameters:
        dataframe (pandas.DataFrame): DataFrame on which to operate
    '''
    data_df['Fare'].fillna(data_df['Fare'].mean(), inplace=True)


def family_survival(data_df, train_df, test_df):
    '''
    Function to get family survival rate

    Parameters:
        dataframe (pandas.DataFrame): DataFrame on which to operate
        dataframe (pandas.DataFrame): DataFrame on which to train
        dataframe (pandas.DataFrame): DataFrame on which to test
    '''
    DEFAULT_SURVIVAL_VALUE = 0.5
    data_df['Family_Survival'] = DEFAULT_SURVIVAL_VALUE

    for grp, grp_df in data_df[['Survived','Name', 'Last_Name', 'Fare', 'Ticket', 'PassengerId',
                            'SibSp', 'Parch', 'Age', 'Cabin']].groupby(['Last_Name', 'Fare']):

        if (len(grp_df) != 1):
            # A Family group is found.
            for ind, row in grp_df.iterrows():
                smax = grp_df.drop(ind)['Survived'].max()
                smin = grp_df.drop(ind)['Survived'].min()
                passID = row['PassengerId']
                if (smax == 1.0):
                    data_df.loc[data_df['PassengerId'] == passID, 'Family_Survival'] = 1
                elif (smin==0.0):
                    data_df.loc[data_df['PassengerId'] == passID, 'Family_Survival'] = 0
    for _, grp_df in data_df.groupby('Ticket'):
        if (len(grp_df) != 1):
            for ind, row in grp_df.iterrows():
                if (row['Family_Survival'] == 0) | (row['Family_Survival']== 0.5):
                    smax = grp_df.drop(ind)['Survived'].max()
                    smin = grp_df.drop(ind)['Survived'].min()
                    passID = row['PassengerId']
                    if (smax == 1.0):
                        data_df.loc[data_df['PassengerId'] == passID, 'Family_Survival'] = 1
                    elif (smin==0.0):
                        data_df.loc[data_df['PassengerId'] == passID, 'Family_Survival'] = 0

    # # Family_Survival in TRAIN_DF and TEST_DF:
    train_df['Family_Survival'] = data_df['Family_Survival'][:891]
    test_df['Family_Survival'] = data_df['Family_Survival'][891:]

def fare_bin(data_df, train_df, test_df):
    '''
    Function to get fare bin and encode it

    Parameters:
        dataframe (pandas.DataFrame): DataFrame on which to operate
        dataframe (pandas.DataFrame): DataFrame on which to train
        dataframe (pandas.DataFrame): DataFrame on which to test
    '''
    data_df['Fare'].fillna(data_df['Fare'].median(), inplace = True)
    data_df['FareBin'] = pd.qcut(data_df['Fare'], 5)

    label = LabelEncoder()
    data_df['FareBin_Code'] = label.fit_transform(data_df['FareBin'])

    train_df['FareBin_Code'] = data_df['FareBin_Code'][:891]
    test_df['FareBin_Code'] = data_df['FareBin_Code'][891:]

    train_df.drop(['Fare'], axis=1, inplace=True)
    test_df.drop(['Fare'], axis=1, inplace=True)

def age_bin(data_df, train_df, test_df):
    '''
    Function to get age bin and encode it

    Parameters:
        dataframe (pandas.DataFrame): DataFrame on which to operate
        dataframe (pandas.DataFrame): DataFrame on which to train
        dataframe (pandas.DataFrame): DataFrame on which to test
    '''
    data_df['AgeBin'] = pd.qcut(data_df['Age'], 4)

    label = LabelEncoder()
    data_df['AgeBin_Code'] = label.fit_transform(data_df['AgeBin'])

    train_df['AgeBin_Code'] = data_df['AgeBin_Code'][:891]
    test_df['AgeBin_Code'] = data_df['AgeBin_Code'][891:]

    train_df.drop(['Age'], axis=1, inplace=True)
    test_df.drop(['Age'], axis=1, inplace=True)

def replacing_sex(train_df, test_df):
    '''    
    Function to replace sex to male or female

    Parameters:
        dataframe (pandas.DataFrame): DataFrame on which to train
        dataframe (pandas.DataFrame): DataFrame on which to test
    '''
    train_df['Sex'].replace(['male','female'],[0,1],inplace=True)
    test_df['Sex'].replace(['male','female'],[0,1],inplace=True)

def aplying_preprocesing(data_df,train_df, test_df):
    '''
    Function to apply preprocesing and drop columns

    Parameters:
        dataframe (pandas.DataFrame): DataFrame on which to operate
        dataframe (pandas.DataFrame): DataFrame on which to train
        dataframe (pandas.DataFrame): DataFrame on which to test
    '''
    extracting_title_age_imputing(data_df, train_df, test_df)
    family_size(data_df, train_df, test_df)
    spliting_name(data_df)
    imputing_fare(data_df)
    family_survival(data_df, train_df, test_df)
    fare_bin(data_df, train_df, test_df)
    age_bin(data_df, train_df, test_df)
    replacing_sex(train_df, test_df)
    train_df.drop(['Name', 'PassengerId', 'SibSp', 'Parch', 'Ticket', 'Cabin',
               'Embarked'], axis = 1, inplace = True)
    test_df.drop(['Name','PassengerId', 'SibSp', 'Parch', 'Ticket', 'Cabin',
              'Embarked'], axis = 1, inplace = True)

# %% [markdown]
# ## XGBoost

# %%
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
data_df = pd.concat([train_df, test_df])

aplying_preprocesing(data_df, train_df, test_df)

X = train_df.drop('Survived', axis=1)
y = train_df['Survived']

std_scaler = StandardScaler()
X = std_scaler.fit_transform(X)

# %%
parameters = {
'max_depth' : [3, 5, 10, 15],
'subsample' : [0.1, 0.3, 0.5, 0.8, 1],
'n_estimators' : [100,250, 500,750, 1000],
'learning_rate' : [0.02, 0.05,0.1]
}

# %%
folds = 5
param_comb = 10

kf = KFold(n_splits = folds, shuffle = True, random_state = 42)
xgb = XGBClassifier()
random_search = GridSearchCV(xgb, param_grid=parameters, scoring='roc_auc', cv = kf.split(X, y), verbose = 3)

start_time = timer(None) 
random_search.fit(X, y)
timer(start_time)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# [CV 1/5] END learning_rate=0.02, max_depth=3, n_estimators=100, subsample=0.1;, score=0.909 total time=   0.3s
# [CV 2/5] END learning_rate=0.02, max_depth=3, n_estimators=100, subsample=0.1;, score=0.840 total time=   0.2s
# [CV 3/5] END learning_rate=0.02, max_depth=3, n_estimators=100, subsample=0.1;, score=0.914 total time=   0.3s
# [CV 4/5] END learning_rate=0.02, max_depth=3, n_estimators=100, subsample=0.1;, score=0.815 total time=   0.3s
# [CV 5/5] END learning_rate=0.02, max_depth=3, n_estimators=100, subsample=0.1;, score=0.887 total time=   0.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [55], in <cell line: 9>()
#       6 random_search = GridSearchCV(xgb, param_grid=parameters, scoring='roc_auc', cv = kf.split(X, y), verbose = 3)
#       8 start_time = timer(None)
# ----> 9 random_search.fit(X, y)
#      10 timer(start_time)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1375, in GridSearchCV._run_search(self, evaluate_candidates)
#    1373 def _run_search(self, evaluate_candidates):
#    1374     """Search all candidates in param_grid"""
# -> 1375     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File /opt/conda/lib/python3.10/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /opt/conda/lib/python3.10/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File /opt/conda/lib/python3.10/site-packages/xgboost/core.py:575, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     573 for k, arg in zip(sig.parameters, args):
#     574     kwargs[k] = arg
# --> 575 return f(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:1400, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1379 model, metric, params, early_stopping_rounds, callbacks = self._configure_fit(
#    1380     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1381 )
#    1382 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1383     missing=self.missing,
#    1384     X=X,
#    (...)
#    1397     enable_categorical=self.enable_categorical,
#    1398 )
# -> 1400 self._Booster = train(
#    1401     params,
#    1402     train_dmatrix,
#    1403     self.get_num_boosting_rounds(),
#    1404     evals=evals,
#    1405     early_stopping_rounds=early_stopping_rounds,
#    1406     evals_result=evals_result,
#    1407     obj=obj,
#    1408     custom_metric=metric,
#    1409     verbose_eval=verbose,
#    1410     xgb_model=model,
#    1411     callbacks=callbacks,
#    1412 )
#    1414 if not callable(self.objective):
#    1415     self.objective = params["objective"]
#
# File /opt/conda/lib/python3.10/site-packages/xgboost/core.py:575, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     573 for k, arg in zip(sig.parameters, args):
#     574     kwargs[k] = arg
# --> 575 return f(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File /opt/conda/lib/python3.10/site-packages/xgboost/core.py:1778, in Booster.update(self, dtrain, iteration, fobj)
#    1775 self._validate_features(dtrain)
#    1777 if fobj is None:
# -> 1778     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1779                                             ctypes.c_int(iteration),
#    1780                                             dtrain.handle))
#    1781 else:
#    1782     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
#print('\n All results:')
#print(random_search.cv_results_)
print('\n Best estimator:')
print(random_search.best_estimator_)
#print('\n Best normalized gini score for %d-fold search with %d parameter combinations:' % (folds, param_comb))
#print(random_search.best_score_ * 2 - 1)
print('\n Best hyperparameters:')
print(random_search.best_params_)
#results = pd.DataFrame(random_search.cv_results_)
#results.to_csv('xgb-random-grid-search-results-01.csv', index=False)
# Out:
#  Best estimator:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=250,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)
#
#  Best hyperparameters:
# {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 250, 'subsample': 0.1}

# %% [markdown]
# ### XGB test

# %%
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
data_df = pd.concat([train_df, test_df])

aplying_preprocesing(data_df, train_df, test_df)

X = train_df.drop('Survived', axis=1)
y = train_df['Survived']
X_test_kaggle = test_df.copy()

std_scaler = StandardScaler()
X = std_scaler.fit_transform(X)
X_test_kaggle = std_scaler.transform(X_test_kaggle)

k_fold = KFold(
    n_splits=N_SPLITS,
    shuffle=True,
    random_state=RANDOM_STATE
)

scores = []

for train_index, test_index in k_fold.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y.loc[train_index], y.loc[test_index]

    xgb = XGBClassifier(learning_rate=0.05, max_depth=10, n_estimators=250, subsample=0.1)
    xgb.fit(X_train, y_train)
    y_predict = xgb.predict(X_test)

    acc_score = round(accuracy_score(y_test, y_predict),3)

    print(acc_score)

    scores.append(acc_score)

print()
print("Average:", round(100*np.mean(scores), 1), "%")
print("Std:", round(100*np.std(scores), 1), "%")
# Out:
# 0.877
# 0.826
# 0.888
# 0.815
# 0.843
#
# Average: 85.0 %
# Std: 2.8 %

# %% [markdown]
# ## CatBoost

# %%
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
data_df = pd.concat([train_df, test_df])

aplying_preprocesing(data_df, train_df, test_df)

X = train_df.drop('Survived', axis=1)
y = train_df['Survived']

std_scaler = StandardScaler()
X = std_scaler.fit_transform(X)

# %%
parameters = {
'iterations' : [50,100,250,500, 750, 1000],
'depth' : [1, 3, 5,6, 7,8, 9, 10],
'learning_rate' : [0.01,0.025,0.05, 0.1, 0.3],
'l2_leaf_reg' : [1, 3, 5, 10, 100],
'random_strength' : [10,20,50,42,1512],
'bagging_temperature' : [0, 0.1, 0.5,1,10,100],
'logging_level' : ['Silent']
}

# %%
folds = 5
param_comb = 100

kf = KFold(n_splits = folds, shuffle = True, random_state = 42)
cbc = CatBoostClassifier()
random_search = RandomizedSearchCV(cbc, param_distributions=parameters, scoring='roc_auc', cv = kf.split(X, y), verbose = 3, n_iter=param_comb)

start_time = timer(None) 
random_search.fit(X, y)
timer(start_time)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END bagging_temperature=100, depth=8, iterations=50, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.887 total time=   0.3s
# [CV 2/5] END bagging_temperature=100, depth=8, iterations=50, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.811 total time=   0.2s
# [CV 3/5] END bagging_temperature=100, depth=8, iterations=50, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.904 total time=   0.2s
# [CV 4/5] END bagging_temperature=100, depth=8, iterations=50, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.800 total time=   0.2s
# [CV 5/5] END bagging_temperature=100, depth=8, iterations=50, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.881 total time=   0.2s
# [CV 1/5] END bagging_temperature=100, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.916 total time=   1.0s
# [CV 2/5] END bagging_temperature=100, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.848 total time=   1.1s
# [CV 3/5] END bagging_temperature=100, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.913 total time=   1.0s
# [CV 4/5] END bagging_temperature=100, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.842 total time=   1.1s
# [CV 5/5] END bagging_temperature=100, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.893 total time=   1.2s
# [CV 1/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.919 total time=   0.3s
# [CV 2/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.830 total time=   0.2s
# [CV 3/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.909 total time=   0.2s
# [CV 4/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.841 total time=   0.2s
# [CV 5/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.888 total time=   0.3s
# [CV 1/5] END bagging_temperature=1, depth=8, iterations=750, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.916 total time=   0.9s
# [CV 2/5] END bagging_temperature=1, depth=8, iterations=750, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.827 total time=   0.9s
# [CV 3/5] END bagging_temperature=1, depth=8, iterations=750, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.904 total time=   1.0s
# [CV 4/5] END bagging_temperature=1, depth=8, iterations=750, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.836 total time=   1.0s
# [CV 5/5] END bagging_temperature=1, depth=8, iterations=750, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.878 total time=   1.0s
# [CV 1/5] END bagging_temperature=0, depth=3, iterations=1000, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.924 total time=   1.0s
# [CV 2/5] END bagging_temperature=0, depth=3, iterations=1000, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.862 total time=   1.0s
# [CV 3/5] END bagging_temperature=0, depth=3, iterations=1000, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.911 total time=   1.0s
# [CV 4/5] END bagging_temperature=0, depth=3, iterations=1000, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.820 total time=   1.0s
# [CV 5/5] END bagging_temperature=0, depth=3, iterations=1000, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.900 total time=   1.0s
# [CV 1/5] END bagging_temperature=0, depth=1, iterations=250, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.906 total time=   0.6s
# [CV 2/5] END bagging_temperature=0, depth=1, iterations=250, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.845 total time=   0.4s
# [CV 3/5] END bagging_temperature=0, depth=1, iterations=250, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.894 total time=   0.4s
# [CV 4/5] END bagging_temperature=0, depth=1, iterations=250, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.781 total time=   0.4s
# [CV 5/5] END bagging_temperature=0, depth=1, iterations=250, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.885 total time=   0.4s
# [CV 1/5] END bagging_temperature=1, depth=10, iterations=100, l2_leaf_reg=10, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.919 total time=   0.3s
# [CV 2/5] END bagging_temperature=1, depth=10, iterations=100, l2_leaf_reg=10, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.830 total time=   0.3s
# [CV 3/5] END bagging_temperature=1, depth=10, iterations=100, l2_leaf_reg=10, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.911 total time=   0.2s
# [CV 4/5] END bagging_temperature=1, depth=10, iterations=100, l2_leaf_reg=10, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.830 total time=   0.3s
# [CV 5/5] END bagging_temperature=1, depth=10, iterations=100, l2_leaf_reg=10, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.881 total time=   0.3s
# [CV 1/5] END bagging_temperature=0, depth=3, iterations=500, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=1512;, score=0.927 total time=   0.6s
# [CV 2/5] END bagging_temperature=0, depth=3, iterations=500, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=1512;, score=0.861 total time=   0.7s
# [CV 3/5] END bagging_temperature=0, depth=3, iterations=500, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=1512;, score=0.916 total time=   0.6s
# [CV 4/5] END bagging_temperature=0, depth=3, iterations=500, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=1512;, score=0.840 total time=   0.6s
# [CV 5/5] END bagging_temperature=0, depth=3, iterations=500, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=1512;, score=0.899 total time=   0.6s
# [CV 1/5] END bagging_temperature=0.1, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.903 total time=   1.1s
# [CV 2/5] END bagging_temperature=0.1, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.830 total time=   1.1s
# [CV 3/5] END bagging_temperature=0.1, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.897 total time=   1.1s
# [CV 4/5] END bagging_temperature=0.1, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.837 total time=   1.1s
# [CV 5/5] END bagging_temperature=0.1, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.839 total time=   1.2s
# [CV 1/5] END bagging_temperature=10, depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.929 total time=   0.6s
# [CV 2/5] END bagging_temperature=10, depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.863 total time=   0.6s
# [CV 3/5] END bagging_temperature=10, depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.914 total time=   0.6s
# [CV 4/5] END bagging_temperature=10, depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.841 total time=   0.6s
# [CV 5/5] END bagging_temperature=10, depth=6, iterations=500, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.898 total time=   0.6s
# [CV 1/5] END bagging_temperature=100, depth=8, iterations=750, l2_leaf_reg=10, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.922 total time=   0.8s
# [CV 2/5] END bagging_temperature=100, depth=8, iterations=750, l2_leaf_reg=10, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.857 total time=   0.8s
# [CV 3/5] END bagging_temperature=100, depth=8, iterations=750, l2_leaf_reg=10, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.917 total time=   0.8s
# [CV 4/5] END bagging_temperature=100, depth=8, iterations=750, l2_leaf_reg=10, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.832 total time=   1.0s
# [CV 5/5] END bagging_temperature=100, depth=8, iterations=750, l2_leaf_reg=10, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.892 total time=   0.8s
# [CV 1/5] END bagging_temperature=10, depth=1, iterations=100, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.881 total time=   0.2s
# [CV 2/5] END bagging_temperature=10, depth=1, iterations=100, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.825 total time=   0.2s
# [CV 3/5] END bagging_temperature=10, depth=1, iterations=100, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.874 total time=   0.2s
# [CV 4/5] END bagging_temperature=10, depth=1, iterations=100, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.771 total time=   0.4s
# [CV 5/5] END bagging_temperature=10, depth=1, iterations=100, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.858 total time=   0.3s
# [CV 1/5] END bagging_temperature=10, depth=6, iterations=750, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.913 total time=   0.9s
# [CV 2/5] END bagging_temperature=10, depth=6, iterations=750, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.837 total time=   1.0s
# [CV 3/5] END bagging_temperature=10, depth=6, iterations=750, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.900 total time=   0.8s
# [CV 4/5] END bagging_temperature=10, depth=6, iterations=750, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.835 total time=   0.9s
# [CV 5/5] END bagging_temperature=10, depth=6, iterations=750, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.859 total time=   1.4s
# [CV 1/5] END bagging_temperature=0.5, depth=7, iterations=50, l2_leaf_reg=1, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.925 total time=   0.5s
# [CV 2/5] END bagging_temperature=0.5, depth=7, iterations=50, l2_leaf_reg=1, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.838 total time=   0.3s
# [CV 3/5] END bagging_temperature=0.5, depth=7, iterations=50, l2_leaf_reg=1, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.915 total time=   0.2s
# [CV 4/5] END bagging_temperature=0.5, depth=7, iterations=50, l2_leaf_reg=1, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.810 total time=   0.2s
# [CV 5/5] END bagging_temperature=0.5, depth=7, iterations=50, l2_leaf_reg=1, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.900 total time=   0.2s
# [CV 1/5] END bagging_temperature=0, depth=7, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=1512;, score=0.914 total time=   1.1s
# [CV 2/5] END bagging_temperature=0, depth=7, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=1512;, score=0.864 total time=   1.1s
# [CV 3/5] END bagging_temperature=0, depth=7, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=1512;, score=0.907 total time=   1.1s
# [CV 4/5] END bagging_temperature=0, depth=7, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=1512;, score=0.842 total time=   1.0s
# [CV 5/5] END bagging_temperature=0, depth=7, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=1512;, score=0.897 total time=   1.1s
# [CV 1/5] END bagging_temperature=100, depth=7, iterations=100, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.913 total time=   0.3s
# [CV 2/5] END bagging_temperature=100, depth=7, iterations=100, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.839 total time=   0.3s
# [CV 3/5] END bagging_temperature=100, depth=7, iterations=100, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.914 total time=   0.2s
# [CV 4/5] END bagging_temperature=100, depth=7, iterations=100, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.808 total time=   0.2s
# [CV 5/5] END bagging_temperature=100, depth=7, iterations=100, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.888 total time=   0.2s
# [CV 1/5] END bagging_temperature=0.1, depth=10, iterations=500, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.909 total time=   0.8s
# [CV 2/5] END bagging_temperature=0.1, depth=10, iterations=500, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.830 total time=   0.8s
# [CV 3/5] END bagging_temperature=0.1, depth=10, iterations=500, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.892 total time=   0.8s
# [CV 4/5] END bagging_temperature=0.1, depth=10, iterations=500, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.840 total time=   0.7s
# [CV 5/5] END bagging_temperature=0.1, depth=10, iterations=500, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.840 total time=   0.8s
# [CV 1/5] END bagging_temperature=0.5, depth=9, iterations=50, l2_leaf_reg=5, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.921 total time=   0.2s
# [CV 2/5] END bagging_temperature=0.5, depth=9, iterations=50, l2_leaf_reg=5, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.839 total time=   0.2s
# [CV 3/5] END bagging_temperature=0.5, depth=9, iterations=50, l2_leaf_reg=5, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.914 total time=   0.3s
# [CV 4/5] END bagging_temperature=0.5, depth=9, iterations=50, l2_leaf_reg=5, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.814 total time=   0.3s
# [CV 5/5] END bagging_temperature=0.5, depth=9, iterations=50, l2_leaf_reg=5, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.890 total time=   0.3s
# [CV 1/5] END bagging_temperature=100, depth=7, iterations=1000, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.918 total time=   1.2s
# [CV 2/5] END bagging_temperature=100, depth=7, iterations=1000, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.837 total time=   1.2s
# [CV 3/5] END bagging_temperature=100, depth=7, iterations=1000, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.909 total time=   1.2s
# [CV 4/5] END bagging_temperature=100, depth=7, iterations=1000, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.833 total time=   1.3s
# [CV 5/5] END bagging_temperature=100, depth=7, iterations=1000, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.894 total time=   1.2s
# [CV 1/5] END bagging_temperature=100, depth=7, iterations=50, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.908 total time=   0.2s
# [CV 2/5] END bagging_temperature=100, depth=7, iterations=50, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.836 total time=   0.2s
# [CV 3/5] END bagging_temperature=100, depth=7, iterations=50, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.907 total time=   0.3s
# [CV 4/5] END bagging_temperature=100, depth=7, iterations=50, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.808 total time=   0.2s
# [CV 5/5] END bagging_temperature=100, depth=7, iterations=50, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.886 total time=   0.2s
# [CV 1/5] END bagging_temperature=10, depth=3, iterations=100, l2_leaf_reg=3, learning_rate=0.01, logging_level=Silent, random_strength=1512;, score=0.912 total time=   0.3s
# [CV 2/5] END bagging_temperature=10, depth=3, iterations=100, l2_leaf_reg=3, learning_rate=0.01, logging_level=Silent, random_strength=1512;, score=0.848 total time=   0.2s
# [CV 3/5] END bagging_temperature=10, depth=3, iterations=100, l2_leaf_reg=3, learning_rate=0.01, logging_level=Silent, random_strength=1512;, score=0.901 total time=   0.2s
# [CV 4/5] END bagging_temperature=10, depth=3, iterations=100, l2_leaf_reg=3, learning_rate=0.01, logging_level=Silent, random_strength=1512;, score=0.800 total time=   0.3s
# [CV 5/5] END bagging_temperature=10, depth=3, iterations=100, l2_leaf_reg=3, learning_rate=0.01, logging_level=Silent, random_strength=1512;, score=0.897 total time=   0.2s
# [CV 1/5] END bagging_temperature=10, depth=5, iterations=100, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.923 total time=   0.4s
# [CV 2/5] END bagging_temperature=10, depth=5, iterations=100, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.854 total time=   0.4s
# [CV 3/5] END bagging_temperature=10, depth=5, iterations=100, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.914 total time=   0.3s
# [CV 4/5] END bagging_temperature=10, depth=5, iterations=100, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.825 total time=   0.4s
# [CV 5/5] END bagging_temperature=10, depth=5, iterations=100, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.895 total time=   0.3s
# [CV 1/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.902 total time=   0.3s
# [CV 2/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.824 total time=   0.2s
# [CV 3/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.913 total time=   0.4s
# [CV 4/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.801 total time=   0.2s
# [CV 5/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.880 total time=   0.3s
# [CV 1/5] END bagging_temperature=0.5, depth=1, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.925 total time=   0.9s
# [CV 2/5] END bagging_temperature=0.5, depth=1, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.863 total time=   1.0s
# [CV 3/5] END bagging_temperature=0.5, depth=1, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.897 total time=   0.9s
# [CV 4/5] END bagging_temperature=0.5, depth=1, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.817 total time=   1.0s
# [CV 5/5] END bagging_temperature=0.5, depth=1, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.894 total time=   1.0s
# [CV 1/5] END bagging_temperature=10, depth=6, iterations=50, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.914 total time=   0.2s
# [CV 2/5] END bagging_temperature=10, depth=6, iterations=50, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.839 total time=   0.2s
# [CV 3/5] END bagging_temperature=10, depth=6, iterations=50, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.907 total time=   0.2s
# [CV 4/5] END bagging_temperature=10, depth=6, iterations=50, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.804 total time=   0.2s
# [CV 5/5] END bagging_temperature=10, depth=6, iterations=50, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=1512;, score=0.895 total time=   0.2s
# [CV 1/5] END bagging_temperature=0.1, depth=8, iterations=250, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.920 total time=   0.5s
# [CV 2/5] END bagging_temperature=0.1, depth=8, iterations=250, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.844 total time=   0.5s
# [CV 3/5] END bagging_temperature=0.1, depth=8, iterations=250, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.914 total time=   0.4s
# [CV 4/5] END bagging_temperature=0.1, depth=8, iterations=250, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.818 total time=   0.6s
# [CV 5/5] END bagging_temperature=0.1, depth=8, iterations=250, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.884 total time=   0.4s
# [CV 1/5] END bagging_temperature=0.1, depth=10, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.915 total time=   1.1s
# [CV 2/5] END bagging_temperature=0.1, depth=10, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.850 total time=   1.2s
# [CV 3/5] END bagging_temperature=0.1, depth=10, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.906 total time=   1.1s
# [CV 4/5] END bagging_temperature=0.1, depth=10, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.846 total time=   1.3s
# [CV 5/5] END bagging_temperature=0.1, depth=10, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.891 total time=   1.2s
# [CV 1/5] END bagging_temperature=100, depth=5, iterations=250, l2_leaf_reg=10, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.911 total time=   0.4s
# [CV 2/5] END bagging_temperature=100, depth=5, iterations=250, l2_leaf_reg=10, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.835 total time=   0.4s
# [CV 3/5] END bagging_temperature=100, depth=5, iterations=250, l2_leaf_reg=10, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.902 total time=   0.5s
# [CV 4/5] END bagging_temperature=100, depth=5, iterations=250, l2_leaf_reg=10, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.829 total time=   0.4s
# [CV 5/5] END bagging_temperature=100, depth=5, iterations=250, l2_leaf_reg=10, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.868 total time=   0.4s
# [CV 1/5] END bagging_temperature=0.5, depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.928 total time=   0.4s
# [CV 2/5] END bagging_temperature=0.5, depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.851 total time=   0.3s
# [CV 3/5] END bagging_temperature=0.5, depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.914 total time=   0.3s
# [CV 4/5] END bagging_temperature=0.5, depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.818 total time=   0.3s
# [CV 5/5] END bagging_temperature=0.5, depth=6, iterations=100, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.902 total time=   0.2s
# [CV 1/5] END bagging_temperature=0.5, depth=1, iterations=500, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.927 total time=   0.6s
# [CV 2/5] END bagging_temperature=0.5, depth=1, iterations=500, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.857 total time=   0.7s
# [CV 3/5] END bagging_temperature=0.5, depth=1, iterations=500, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.897 total time=   0.5s
# [CV 4/5] END bagging_temperature=0.5, depth=1, iterations=500, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.817 total time=   0.7s
# [CV 5/5] END bagging_temperature=0.5, depth=1, iterations=500, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.891 total time=   0.6s
# [CV 1/5] END bagging_temperature=0, depth=5, iterations=500, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.908 total time=   0.6s
# [CV 2/5] END bagging_temperature=0, depth=5, iterations=500, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.837 total time=   0.7s
# [CV 3/5] END bagging_temperature=0, depth=5, iterations=500, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.897 total time=   0.6s
# [CV 4/5] END bagging_temperature=0, depth=5, iterations=500, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.835 total time=   0.8s
# [CV 5/5] END bagging_temperature=0, depth=5, iterations=500, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.852 total time=   0.7s
# [CV 1/5] END bagging_temperature=100, depth=3, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.904 total time=   1.0s
# [CV 2/5] END bagging_temperature=100, depth=3, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.829 total time=   1.2s
# [CV 3/5] END bagging_temperature=100, depth=3, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.877 total time=   1.1s
# [CV 4/5] END bagging_temperature=100, depth=3, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.839 total time=   1.0s
# [CV 5/5] END bagging_temperature=100, depth=3, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.868 total time=   1.3s
# [CV 1/5] END bagging_temperature=10, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.925 total time=   0.2s
# [CV 2/5] END bagging_temperature=10, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.841 total time=   0.2s
# [CV 3/5] END bagging_temperature=10, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.916 total time=   0.2s
# [CV 4/5] END bagging_temperature=10, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.839 total time=   0.3s
# [CV 5/5] END bagging_temperature=10, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.894 total time=   0.2s
# [CV 1/5] END bagging_temperature=0, depth=7, iterations=750, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.910 total time=   0.9s
# [CV 2/5] END bagging_temperature=0, depth=7, iterations=750, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.834 total time=   1.0s
# [CV 3/5] END bagging_temperature=0, depth=7, iterations=750, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.901 total time=   1.0s
# [CV 4/5] END bagging_temperature=0, depth=7, iterations=750, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.837 total time=   0.9s
# [CV 5/5] END bagging_temperature=0, depth=7, iterations=750, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=50;, score=0.854 total time=   1.0s
# [CV 1/5] END bagging_temperature=0.5, depth=5, iterations=1000, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=10;, score=0.917 total time=   1.1s
# [CV 2/5] END bagging_temperature=0.5, depth=5, iterations=1000, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=10;, score=0.832 total time=   1.1s
# [CV 3/5] END bagging_temperature=0.5, depth=5, iterations=1000, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=10;, score=0.915 total time=   1.4s
# [CV 4/5] END bagging_temperature=0.5, depth=5, iterations=1000, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=10;, score=0.845 total time=   1.3s
# [CV 5/5] END bagging_temperature=0.5, depth=5, iterations=1000, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=10;, score=0.888 total time=   1.3s
# [CV 1/5] END bagging_temperature=1, depth=9, iterations=750, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.911 total time=   1.1s
# [CV 2/5] END bagging_temperature=1, depth=9, iterations=750, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.833 total time=   1.0s
# [CV 3/5] END bagging_temperature=1, depth=9, iterations=750, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.897 total time=   0.9s
# [CV 4/5] END bagging_temperature=1, depth=9, iterations=750, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.839 total time=   0.9s
# [CV 5/5] END bagging_temperature=1, depth=9, iterations=750, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.862 total time=   0.9s
# [CV 1/5] END bagging_temperature=1, depth=7, iterations=500, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=50;, score=0.924 total time=   0.7s
# [CV 2/5] END bagging_temperature=1, depth=7, iterations=500, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=50;, score=0.855 total time=   0.7s
# [CV 3/5] END bagging_temperature=1, depth=7, iterations=500, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=50;, score=0.914 total time=   0.7s
# [CV 4/5] END bagging_temperature=1, depth=7, iterations=500, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=50;, score=0.822 total time=   0.7s
# [CV 5/5] END bagging_temperature=1, depth=7, iterations=500, l2_leaf_reg=100, learning_rate=0.025, logging_level=Silent, random_strength=50;, score=0.890 total time=   0.7s
# [CV 1/5] END bagging_temperature=0.1, depth=10, iterations=100, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.895 total time=   0.3s
# [CV 2/5] END bagging_temperature=0.1, depth=10, iterations=100, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.822 total time=   0.3s
# [CV 3/5] END bagging_temperature=0.1, depth=10, iterations=100, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.914 total time=   0.3s
# [CV 4/5] END bagging_temperature=0.1, depth=10, iterations=100, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.799 total time=   0.3s
# [CV 5/5] END bagging_temperature=0.1, depth=10, iterations=100, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.878 total time=   0.3s
# [CV 1/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=10, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.909 total time=   0.3s
# [CV 2/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=10, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.832 total time=   0.2s
# [CV 3/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=10, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.919 total time=   0.2s
# [CV 4/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=10, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.813 total time=   0.3s
# [CV 5/5] END bagging_temperature=0.1, depth=8, iterations=100, l2_leaf_reg=10, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.886 total time=   0.2s
# [CV 1/5] END bagging_temperature=10, depth=9, iterations=250, l2_leaf_reg=100, learning_rate=0.3, logging_level=Silent, random_strength=42;, score=0.915 total time=   0.6s
# [CV 2/5] END bagging_temperature=10, depth=9, iterations=250, l2_leaf_reg=100, learning_rate=0.3, logging_level=Silent, random_strength=42;, score=0.829 total time=   0.6s
# [CV 3/5] END bagging_temperature=10, depth=9, iterations=250, l2_leaf_reg=100, learning_rate=0.3, logging_level=Silent, random_strength=42;, score=0.904 total time=   0.5s
# [CV 4/5] END bagging_temperature=10, depth=9, iterations=250, l2_leaf_reg=100, learning_rate=0.3, logging_level=Silent, random_strength=42;, score=0.839 total time=   0.5s
# [CV 5/5] END bagging_temperature=10, depth=9, iterations=250, l2_leaf_reg=100, learning_rate=0.3, logging_level=Silent, random_strength=42;, score=0.869 total time=   0.5s
# [CV 1/5] END bagging_temperature=1, depth=5, iterations=500, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.917 total time=   0.7s
# [CV 2/5] END bagging_temperature=1, depth=5, iterations=500, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.845 total time=   0.6s
# [CV 3/5] END bagging_temperature=1, depth=5, iterations=500, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.914 total time=   0.6s
# [CV 4/5] END bagging_temperature=1, depth=5, iterations=500, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.814 total time=   0.7s
# [CV 5/5] END bagging_temperature=1, depth=5, iterations=500, l2_leaf_reg=100, learning_rate=0.01, logging_level=Silent, random_strength=10;, score=0.890 total time=   0.7s
# [CV 1/5] END bagging_temperature=0.1, depth=9, iterations=100, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=1512;, score=0.926 total time=   0.3s
# [CV 2/5] END bagging_temperature=0.1, depth=9, iterations=100, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=1512;, score=0.850 total time=   0.3s
# [CV 3/5] END bagging_temperature=0.1, depth=9, iterations=100, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=1512;, score=0.915 total time=   0.3s
# [CV 4/5] END bagging_temperature=0.1, depth=9, iterations=100, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=1512;, score=0.826 total time=   0.3s
# [CV 5/5] END bagging_temperature=0.1, depth=9, iterations=100, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=1512;, score=0.895 total time=   0.2s
# [CV 1/5] END bagging_temperature=0.5, depth=8, iterations=1000, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.915 total time=   1.2s
# [CV 2/5] END bagging_temperature=0.5, depth=8, iterations=1000, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.828 total time=   1.4s
# [CV 3/5] END bagging_temperature=0.5, depth=8, iterations=1000, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.900 total time=   1.3s
# [CV 4/5] END bagging_temperature=0.5, depth=8, iterations=1000, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.837 total time=   1.2s
# [CV 5/5] END bagging_temperature=0.5, depth=8, iterations=1000, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.876 total time=   1.2s
# [CV 1/5] END bagging_temperature=10, depth=1, iterations=1000, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.928 total time=   1.1s
# [CV 2/5] END bagging_temperature=10, depth=1, iterations=1000, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.867 total time=   1.2s
# [CV 3/5] END bagging_temperature=10, depth=1, iterations=1000, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.898 total time=   1.0s
# [CV 4/5] END bagging_temperature=10, depth=1, iterations=1000, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.814 total time=   0.9s
# [CV 5/5] END bagging_temperature=10, depth=1, iterations=1000, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=10;, score=0.892 total time=   1.0s
# [CV 1/5] END bagging_temperature=0.1, depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.926 total time=   0.7s
# [CV 2/5] END bagging_temperature=0.1, depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.859 total time=   0.7s
# [CV 3/5] END bagging_temperature=0.1, depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.914 total time=   0.7s
# [CV 4/5] END bagging_temperature=0.1, depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.835 total time=   0.7s
# [CV 5/5] END bagging_temperature=0.1, depth=6, iterations=500, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.898 total time=   0.8s
# [CV 1/5] END bagging_temperature=0, depth=1, iterations=100, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.897 total time=   0.2s
# [CV 2/5] END bagging_temperature=0, depth=1, iterations=100, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.836 total time=   0.3s
# [CV 3/5] END bagging_temperature=0, depth=1, iterations=100, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.881 total time=   0.2s
# [CV 4/5] END bagging_temperature=0, depth=1, iterations=100, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.778 total time=   0.2s
# [CV 5/5] END bagging_temperature=0, depth=1, iterations=100, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.864 total time=   0.2s
# [CV 1/5] END bagging_temperature=10, depth=8, iterations=250, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.914 total time=   0.7s
# [CV 2/5] END bagging_temperature=10, depth=8, iterations=250, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.837 total time=   0.5s
# [CV 3/5] END bagging_temperature=10, depth=8, iterations=250, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.895 total time=   0.4s
# [CV 4/5] END bagging_temperature=10, depth=8, iterations=250, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.841 total time=   0.4s
# [CV 5/5] END bagging_temperature=10, depth=8, iterations=250, l2_leaf_reg=1, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.872 total time=   0.5s
# [CV 1/5] END bagging_temperature=0.5, depth=1, iterations=500, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.914 total time=   0.9s
# [CV 2/5] END bagging_temperature=0.5, depth=1, iterations=500, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.852 total time=   0.7s
# [CV 3/5] END bagging_temperature=0.5, depth=1, iterations=500, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.900 total time=   0.6s
# [CV 4/5] END bagging_temperature=0.5, depth=1, iterations=500, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.800 total time=   0.6s
# [CV 5/5] END bagging_temperature=0.5, depth=1, iterations=500, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.893 total time=   0.7s
# [CV 1/5] END bagging_temperature=0.1, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.906 total time=   0.8s
# [CV 2/5] END bagging_temperature=0.1, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.826 total time=   0.9s
# [CV 3/5] END bagging_temperature=0.1, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.898 total time=   0.7s
# [CV 4/5] END bagging_temperature=0.1, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.842 total time=   0.8s
# [CV 5/5] END bagging_temperature=0.1, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.841 total time=   0.9s
# [CV 1/5] END bagging_temperature=1, depth=5, iterations=1000, l2_leaf_reg=10, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.914 total time=   1.1s
# [CV 2/5] END bagging_temperature=1, depth=5, iterations=1000, l2_leaf_reg=10, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.834 total time=   1.1s
# [CV 3/5] END bagging_temperature=1, depth=5, iterations=1000, l2_leaf_reg=10, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.907 total time=   1.2s
# [CV 4/5] END bagging_temperature=1, depth=5, iterations=1000, l2_leaf_reg=10, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.836 total time=   1.2s
# [CV 5/5] END bagging_temperature=1, depth=5, iterations=1000, l2_leaf_reg=10, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.871 total time=   1.0s
# [CV 1/5] END bagging_temperature=0.5, depth=8, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.909 total time=   1.2s
# [CV 2/5] END bagging_temperature=0.5, depth=8, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.827 total time=   1.3s
# [CV 3/5] END bagging_temperature=0.5, depth=8, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.899 total time=   1.3s
# [CV 4/5] END bagging_temperature=0.5, depth=8, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.844 total time=   1.4s
# [CV 5/5] END bagging_temperature=0.5, depth=8, iterations=1000, l2_leaf_reg=3, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.847 total time=   1.5s
# [CV 1/5] END bagging_temperature=10, depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.908 total time=   1.3s
# [CV 2/5] END bagging_temperature=10, depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.830 total time=   1.2s
# [CV 3/5] END bagging_temperature=10, depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.898 total time=   1.4s
# [CV 4/5] END bagging_temperature=10, depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.842 total time=   1.3s
# [CV 5/5] END bagging_temperature=10, depth=9, iterations=1000, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.836 total time=   1.4s
# [CV 1/5] END bagging_temperature=10, depth=8, iterations=250, l2_leaf_reg=5, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.916 total time=   0.4s
# [CV 2/5] END bagging_temperature=10, depth=8, iterations=250, l2_leaf_reg=5, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.840 total time=   0.4s
# [CV 3/5] END bagging_temperature=10, depth=8, iterations=250, l2_leaf_reg=5, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.912 total time=   0.4s
# [CV 4/5] END bagging_temperature=10, depth=8, iterations=250, l2_leaf_reg=5, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.846 total time=   0.5s
# [CV 5/5] END bagging_temperature=10, depth=8, iterations=250, l2_leaf_reg=5, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.888 total time=   0.6s
# [CV 1/5] END bagging_temperature=100, depth=5, iterations=100, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.902 total time=   0.2s
# [CV 2/5] END bagging_temperature=100, depth=5, iterations=100, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.824 total time=   0.3s
# [CV 3/5] END bagging_temperature=100, depth=5, iterations=100, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.911 total time=   0.4s
# [CV 4/5] END bagging_temperature=100, depth=5, iterations=100, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.804 total time=   0.3s
# [CV 5/5] END bagging_temperature=100, depth=5, iterations=100, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.881 total time=   0.2s
# [CV 1/5] END bagging_temperature=100, depth=3, iterations=50, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=50;, score=0.914 total time=   0.3s
# [CV 2/5] END bagging_temperature=100, depth=3, iterations=50, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=50;, score=0.849 total time=   0.2s
# [CV 3/5] END bagging_temperature=100, depth=3, iterations=50, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=50;, score=0.906 total time=   0.2s
# [CV 4/5] END bagging_temperature=100, depth=3, iterations=50, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=50;, score=0.801 total time=   0.2s
# [CV 5/5] END bagging_temperature=100, depth=3, iterations=50, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=50;, score=0.893 total time=   0.2s
# [CV 1/5] END bagging_temperature=0.1, depth=9, iterations=250, l2_leaf_reg=100, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.917 total time=   0.6s
# [CV 2/5] END bagging_temperature=0.1, depth=9, iterations=250, l2_leaf_reg=100, learning_rate=0.3, logging_level=Silent, random_strength=20;, score=0.827 total time=   0.7s
# ...
# [CV 3/5] END bagging_temperature=100, depth=3, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.879 total time=   1.1s
# [CV 4/5] END bagging_temperature=100, depth=3, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.841 total time=   1.1s
# [CV 5/5] END bagging_temperature=100, depth=3, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=42;, score=0.866 total time=   1.0s
# [CV 1/5] END bagging_temperature=1, depth=8, iterations=500, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.916 total time=   0.7s
# [CV 2/5] END bagging_temperature=1, depth=8, iterations=500, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.833 total time=   1.3s
# [CV 3/5] END bagging_temperature=1, depth=8, iterations=500, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.908 total time=   0.9s
# [CV 4/5] END bagging_temperature=1, depth=8, iterations=500, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.842 total time=   0.8s
# [CV 5/5] END bagging_temperature=1, depth=8, iterations=500, l2_leaf_reg=100, learning_rate=0.1, logging_level=Silent, random_strength=1512;, score=0.888 total time=   0.7s
# [CV 1/5] END bagging_temperature=0.1, depth=7, iterations=750, l2_leaf_reg=10, learning_rate=0.01, logging_level=Silent, random_strength=50;, score=0.927 total time=   2.7s
# [CV 2/5] END bagging_temperature=0.1, depth=7, iterations=750, l2_leaf_reg=10, learning_rate=0.01, logging_level=Silent, random_strength=50;, score=0.856 total time=   1.8s
# [CV 3/5] END bagging_temperature=0.1, depth=7, iterations=750, l2_leaf_reg=10, learning_rate=0.01, logging_level=Silent, random_strength=50;, score=0.915 total time=   1.3s
# [CV 4/5] END bagging_temperature=0.1, depth=7, iterations=750, l2_leaf_reg=10, learning_rate=0.01, logging_level=Silent, random_strength=50;, score=0.834 total time=   1.1s
# [CV 5/5] END bagging_temperature=0.1, depth=7, iterations=750, l2_leaf_reg=10, learning_rate=0.01, logging_level=Silent, random_strength=50;, score=0.894 total time=   1.2s
# [CV 1/5] END bagging_temperature=0, depth=1, iterations=50, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.928 total time=   0.6s
# [CV 2/5] END bagging_temperature=0, depth=1, iterations=50, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.865 total time=   0.4s
# [CV 3/5] END bagging_temperature=0, depth=1, iterations=50, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.900 total time=   0.4s
# [CV 4/5] END bagging_temperature=0, depth=1, iterations=50, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.812 total time=   0.5s
# [CV 5/5] END bagging_temperature=0, depth=1, iterations=50, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=50;, score=0.895 total time=   0.5s
# [CV 1/5] END bagging_temperature=0, depth=1, iterations=750, l2_leaf_reg=10, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.927 total time=   1.2s
# [CV 2/5] END bagging_temperature=0, depth=1, iterations=750, l2_leaf_reg=10, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.864 total time=   1.2s
# [CV 3/5] END bagging_temperature=0, depth=1, iterations=750, l2_leaf_reg=10, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.898 total time=   1.6s
# [CV 4/5] END bagging_temperature=0, depth=1, iterations=750, l2_leaf_reg=10, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.814 total time=   1.9s
# [CV 5/5] END bagging_temperature=0, depth=1, iterations=750, l2_leaf_reg=10, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.892 total time=   1.2s
# [CV 1/5] END bagging_temperature=1, depth=5, iterations=250, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=50;, score=0.925 total time=   0.9s
# [CV 2/5] END bagging_temperature=1, depth=5, iterations=250, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=50;, score=0.863 total time=   0.7s
# [CV 3/5] END bagging_temperature=1, depth=5, iterations=250, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=50;, score=0.915 total time=   0.6s
# [CV 4/5] END bagging_temperature=1, depth=5, iterations=250, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=50;, score=0.832 total time=   0.8s
# [CV 5/5] END bagging_temperature=1, depth=5, iterations=250, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=50;, score=0.906 total time=   0.8s
# [CV 1/5] END bagging_temperature=0.1, depth=7, iterations=750, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=42;, score=0.913 total time=   1.7s
# [CV 2/5] END bagging_temperature=0.1, depth=7, iterations=750, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=42;, score=0.835 total time=   1.1s
# [CV 3/5] END bagging_temperature=0.1, depth=7, iterations=750, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=42;, score=0.906 total time=   1.0s
# [CV 4/5] END bagging_temperature=0.1, depth=7, iterations=750, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=42;, score=0.840 total time=   1.1s
# [CV 5/5] END bagging_temperature=0.1, depth=7, iterations=750, l2_leaf_reg=3, learning_rate=0.025, logging_level=Silent, random_strength=42;, score=0.871 total time=   1.2s
# [CV 1/5] END bagging_temperature=0, depth=1, iterations=100, l2_leaf_reg=100, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.919 total time=   0.3s
# [CV 2/5] END bagging_temperature=0, depth=1, iterations=100, l2_leaf_reg=100, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.853 total time=   0.4s
# [CV 3/5] END bagging_temperature=0, depth=1, iterations=100, l2_leaf_reg=100, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.900 total time=   0.3s
# [CV 4/5] END bagging_temperature=0, depth=1, iterations=100, l2_leaf_reg=100, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.803 total time=   0.3s
# [CV 5/5] END bagging_temperature=0, depth=1, iterations=100, l2_leaf_reg=100, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.901 total time=   1.4s
# [CV 1/5] END bagging_temperature=0.1, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.909 total time=   1.1s
# [CV 2/5] END bagging_temperature=0.1, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.834 total time=   0.2s
# [CV 3/5] END bagging_temperature=0.1, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.914 total time=   0.2s
# [CV 4/5] END bagging_temperature=0.1, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.809 total time=   0.2s
# [CV 5/5] END bagging_temperature=0.1, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.01, logging_level=Silent, random_strength=20;, score=0.890 total time=   0.2s
# [CV 1/5] END bagging_temperature=1, depth=8, iterations=50, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=42;, score=0.903 total time=   0.3s
# [CV 2/5] END bagging_temperature=1, depth=8, iterations=50, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=42;, score=0.831 total time=   0.2s
# [CV 3/5] END bagging_temperature=1, depth=8, iterations=50, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=42;, score=0.913 total time=   0.2s
# [CV 4/5] END bagging_temperature=1, depth=8, iterations=50, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=42;, score=0.808 total time=   0.2s
# [CV 5/5] END bagging_temperature=1, depth=8, iterations=50, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=42;, score=0.889 total time=   0.3s
# [CV 1/5] END bagging_temperature=0.5, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.917 total time=   1.1s
# [CV 2/5] END bagging_temperature=0.5, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.859 total time=   1.2s
# [CV 3/5] END bagging_temperature=0.5, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.913 total time=   1.1s
# [CV 4/5] END bagging_temperature=0.5, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.839 total time=   1.2s
# [CV 5/5] END bagging_temperature=0.5, depth=7, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, logging_level=Silent, random_strength=42;, score=0.896 total time=   1.6s
# [CV 1/5] END bagging_temperature=0, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.925 total time=   0.4s
# [CV 2/5] END bagging_temperature=0, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.841 total time=   0.4s
# [CV 3/5] END bagging_temperature=0, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.916 total time=   0.4s
# [CV 4/5] END bagging_temperature=0, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.839 total time=   0.3s
# [CV 5/5] END bagging_temperature=0, depth=8, iterations=50, l2_leaf_reg=1, learning_rate=0.3, logging_level=Silent, random_strength=1512;, score=0.894 total time=   0.4s
# [CV 1/5] END bagging_temperature=0.5, depth=10, iterations=500, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=10;, score=0.908 total time=   0.9s
# [CV 2/5] END bagging_temperature=0.5, depth=10, iterations=500, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=10;, score=0.830 total time=   1.1s
# [CV 3/5] END bagging_temperature=0.5, depth=10, iterations=500, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=10;, score=0.894 total time=   1.0s
# [CV 4/5] END bagging_temperature=0.5, depth=10, iterations=500, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=10;, score=0.835 total time=   1.0s
# [CV 5/5] END bagging_temperature=0.5, depth=10, iterations=500, l2_leaf_reg=5, learning_rate=0.1, logging_level=Silent, random_strength=10;, score=0.848 total time=   0.9s
# [CV 1/5] END bagging_temperature=0.5, depth=3, iterations=50, l2_leaf_reg=3, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.922 total time=   0.3s
# [CV 2/5] END bagging_temperature=0.5, depth=3, iterations=50, l2_leaf_reg=3, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.860 total time=   0.4s
# [CV 3/5] END bagging_temperature=0.5, depth=3, iterations=50, l2_leaf_reg=3, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.912 total time=   0.4s
# [CV 4/5] END bagging_temperature=0.5, depth=3, iterations=50, l2_leaf_reg=3, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.816 total time=   0.3s
# [CV 5/5] END bagging_temperature=0.5, depth=3, iterations=50, l2_leaf_reg=3, learning_rate=0.1, logging_level=Silent, random_strength=20;, score=0.901 total time=   0.4s
# [CV 1/5] END bagging_temperature=1, depth=9, iterations=100, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.893 total time=   0.5s
# [CV 2/5] END bagging_temperature=1, depth=9, iterations=100, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.821 total time=   0.4s
# [CV 3/5] END bagging_temperature=1, depth=9, iterations=100, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.911 total time=   0.4s
# [CV 4/5] END bagging_temperature=1, depth=9, iterations=100, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.800 total time=   0.4s
# [CV 5/5] END bagging_temperature=1, depth=9, iterations=100, l2_leaf_reg=100, learning_rate=0.05, logging_level=Silent, random_strength=42;, score=0.884 total time=   0.3s
# [CV 1/5] END bagging_temperature=100, depth=9, iterations=100, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.920 total time=   0.5s
# [CV 2/5] END bagging_temperature=100, depth=9, iterations=100, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.830 total time=   1.1s
# [CV 3/5] END bagging_temperature=100, depth=9, iterations=100, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.910 total time=   1.1s
# [CV 4/5] END bagging_temperature=100, depth=9, iterations=100, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.840 total time=   0.7s
# [CV 5/5] END bagging_temperature=100, depth=9, iterations=100, l2_leaf_reg=5, learning_rate=0.3, logging_level=Silent, random_strength=10;, score=0.880 total time=   0.3s
# [CV 1/5] END bagging_temperature=0.5, depth=1, iterations=100, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=10;, score=0.910 total time=   0.3s
# [CV 2/5] END bagging_temperature=0.5, depth=1, iterations=100, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=10;, score=0.851 total time=   0.4s
# [CV 3/5] END bagging_temperature=0.5, depth=1, iterations=100, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=10;, score=0.893 total time=   0.4s
# [CV 4/5] END bagging_temperature=0.5, depth=1, iterations=100, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=10;, score=0.790 total time=   0.4s
# [CV 5/5] END bagging_temperature=0.5, depth=1, iterations=100, l2_leaf_reg=3, learning_rate=0.05, logging_level=Silent, random_strength=10;, score=0.886 total time=   0.4s
# [CV 1/5] END bagging_temperature=0, depth=3, iterations=500, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.926 total time=   1.1s
# [CV 2/5] END bagging_temperature=0, depth=3, iterations=500, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.855 total time=   1.3s
# [CV 3/5] END bagging_temperature=0, depth=3, iterations=500, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.914 total time=   0.9s
# [CV 4/5] END bagging_temperature=0, depth=3, iterations=500, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.837 total time=   1.0s
# [CV 5/5] END bagging_temperature=0, depth=3, iterations=500, l2_leaf_reg=5, learning_rate=0.025, logging_level=Silent, random_strength=20;, score=0.900 total time=   0.9s
# [CV 1/5] END bagging_temperature=10, depth=7, iterations=100, l2_leaf_reg=10, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.912 total time=   0.3s
# [CV 2/5] END bagging_temperature=10, depth=7, iterations=100, l2_leaf_reg=10, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.841 total time=   0.5s
# [CV 3/5] END bagging_temperature=10, depth=7, iterations=100, l2_leaf_reg=10, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.915 total time=   0.5s
# [CV 4/5] END bagging_temperature=10, depth=7, iterations=100, l2_leaf_reg=10, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.810 total time=   0.4s
# [CV 5/5] END bagging_temperature=10, depth=7, iterations=100, l2_leaf_reg=10, learning_rate=0.05, logging_level=Silent, random_strength=20;, score=0.891 total time=   0.5s
#
#  Time taken: 0 hours 5 minutes and 31.19 seconds.

# %%
#print('\n All results:')
#print(random_search.cv_results_)
print('\n Best estimator:')
print(random_search.best_estimator_)
#print('\n Best normalized gini score for %d-fold search with %d parameter combinations:' % (folds, param_comb))
#print(random_search.best_score_ * 2 - 1)
print('\n Best hyperparameters:')
print(random_search.best_params_)
#results = pd.DataFrame(random_search.cv_results_)
#results.to_csv('xgb-random-grid-search-results-01.csv', index=False)
# Out:
#  Best estimator:
# <catboost.core.CatBoostClassifier object at 0x7f2bd9553ac0>
#
#  Best hyperparameters:
# {'random_strength': 42, 'logging_level': 'Silent', 'learning_rate': 0.01, 'l2_leaf_reg': 1, 'iterations': 250, 'depth': 7, 'bagging_temperature': 0.1}

# %% [markdown]
# ### CatBoost test

# %%
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
data_df = pd.concat([train_df, test_df])

aplying_preprocesing(data_df, train_df, test_df)

X = train_df.drop('Survived', axis=1)
y = train_df['Survived']
X_test_kaggle = test_df.copy()

std_scaler = StandardScaler()
X = std_scaler.fit_transform(X)
X_test_kaggle = std_scaler.transform(X_test_kaggle)

k_fold = KFold(
    n_splits=N_SPLITS,
    shuffle=True,
    random_state=RANDOM_STATE
)

scores = []

for train_index, test_index in k_fold.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y.loc[train_index], y.loc[test_index]

    xgb = CatBoostClassifier(learning_rate=0.01, depth=5, iterations=750,random_strength=42, logging_level= 'Silent', l2_leaf_reg=1, bagging_temperature=0 )
    xgb.fit(X_train, y_train)
    y_predict = xgb.predict(X_test)

    acc_score = round(accuracy_score(y_test, y_predict),3)

    print(acc_score)

    scores.append(acc_score)

print()
print("Average:", round(100*np.mean(scores), 1), "%")
print("Std:", round(100*np.std(scores), 1), "%")
# Out:
# 0.855
# 0.82
# 0.888
# 0.809
# 0.854
#
# Average: 84.5 %
# Std: 2.8 %

# %% [markdown]
# ## SVC

# %%
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
data_df = pd.concat([train_df, test_df])

aplying_preprocesing(data_df, train_df, test_df)

X = train_df.drop('Survived', axis=1)
y = train_df['Survived']

std_scaler = StandardScaler()
X = std_scaler.fit_transform(X)

# %%
parameters = {
'kernel' : ['linear', 'rbf', 'poly'],
'gamma' : [0.1, 0.5, 1, 5, 10, 25, 50 ,100],
'C' : [0.1, 1, 5, 10, 25, 50, 100, 250, 500, 1000],
'degree' : [0, 1, 2, 3, 4, 5, 6]
}

# %%
folds = 5
param_comb = 5000

kf = KFold(n_splits = folds, shuffle = True, random_state = 42)
svc = SVC()
random_search = RandomizedSearchCV(svc, param_distributions=parameters, scoring='roc_auc', cv = kf.split(X, y), verbose = 3, n_iter=param_comb)

start_time = timer(None) 
random_search.fit(X, y)
timer(start_time)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:306: UserWarning: The total space of parameters 1680 is smaller than n_iter=5000. Running 1680 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 1680 candidates, totalling 8400 fits
# [CV 1/5] END C=0.1, degree=0, gamma=0.1, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=0.1, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=0.1, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=0.1, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=0.1, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=0.1, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=0.1, kernel=rbf;, score=0.846 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=0.1, kernel=rbf;, score=0.909 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=0.1, kernel=rbf;, score=0.810 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=0.1, kernel=rbf;, score=0.875 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=0.1, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=0.1, kernel=poly;, score=0.500 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=0.1, kernel=poly;, score=0.500 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=0.1, kernel=poly;, score=0.500 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=0.1, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=0.5, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=0.5, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=0.5, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=0.5, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=0.5, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=0.5, kernel=rbf;, score=0.868 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=0.5, kernel=rbf;, score=0.832 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=0.5, kernel=rbf;, score=0.910 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=0.5, kernel=rbf;, score=0.796 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=0.5, kernel=rbf;, score=0.851 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=0.5, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=0.5, kernel=poly;, score=0.500 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=0.5, kernel=poly;, score=0.500 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=0.5, kernel=poly;, score=0.500 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=0.5, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=1, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=1, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=1, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=1, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=1, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=1, kernel=rbf;, score=0.884 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=1, kernel=rbf;, score=0.811 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=1, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=1, kernel=rbf;, score=0.809 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=1, kernel=rbf;, score=0.831 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=1, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=1, kernel=poly;, score=0.500 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=1, kernel=poly;, score=0.500 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=1, kernel=poly;, score=0.500 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=1, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=5, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=5, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=5, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=5, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=5, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=5, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=5, kernel=rbf;, score=0.777 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=5, kernel=rbf;, score=0.892 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=5, kernel=rbf;, score=0.820 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=5, kernel=rbf;, score=0.808 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=5, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=5, kernel=poly;, score=0.500 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=5, kernel=poly;, score=0.500 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=5, kernel=poly;, score=0.500 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=5, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=10, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=10, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=10, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=10, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=10, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=10, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=10, kernel=rbf;, score=0.784 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=10, kernel=rbf;, score=0.882 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=10, kernel=rbf;, score=0.795 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=10, kernel=rbf;, score=0.813 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=10, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=10, kernel=poly;, score=0.500 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=10, kernel=poly;, score=0.500 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=10, kernel=poly;, score=0.500 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=10, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=25, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=25, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=25, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=25, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=25, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=25, kernel=rbf;, score=0.881 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=25, kernel=rbf;, score=0.784 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=25, kernel=rbf;, score=0.886 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=25, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=25, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=25, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=25, kernel=poly;, score=0.500 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=25, kernel=poly;, score=0.500 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=25, kernel=poly;, score=0.500 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=25, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=50, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=50, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=50, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=50, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=50, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=50, kernel=rbf;, score=0.877 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=50, kernel=rbf;, score=0.778 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=50, kernel=rbf;, score=0.879 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=50, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=50, kernel=rbf;, score=0.809 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=50, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=50, kernel=poly;, score=0.500 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=50, kernel=poly;, score=0.500 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=50, kernel=poly;, score=0.500 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=50, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=100, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=100, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=100, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=100, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=100, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=100, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=100, kernel=rbf;, score=0.773 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=100, kernel=rbf;, score=0.860 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=100, kernel=rbf;, score=0.792 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=100, kernel=rbf;, score=0.802 total time=   0.0s
# [CV 1/5] END C=0.1, degree=0, gamma=100, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/5] END C=0.1, degree=0, gamma=100, kernel=poly;, score=0.500 total time=   0.0s
# [CV 3/5] END C=0.1, degree=0, gamma=100, kernel=poly;, score=0.500 total time=   0.0s
# [CV 4/5] END C=0.1, degree=0, gamma=100, kernel=poly;, score=0.500 total time=   0.0s
# [CV 5/5] END C=0.1, degree=0, gamma=100, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=0.1, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=0.1, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=0.1, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=0.1, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=0.1, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=0.1, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=0.1, kernel=rbf;, score=0.846 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=0.1, kernel=rbf;, score=0.909 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=0.1, kernel=rbf;, score=0.810 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=0.1, kernel=rbf;, score=0.875 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=0.1, kernel=poly;, score=0.901 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=0.1, kernel=poly;, score=0.831 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=0.1, kernel=poly;, score=0.895 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=0.1, kernel=poly;, score=0.789 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=0.1, kernel=poly;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=0.5, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=0.5, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=0.5, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=0.5, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=0.5, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=0.5, kernel=rbf;, score=0.868 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=0.5, kernel=rbf;, score=0.832 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=0.5, kernel=rbf;, score=0.910 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=0.5, kernel=rbf;, score=0.796 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=0.5, kernel=rbf;, score=0.851 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=0.5, kernel=poly;, score=0.892 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=0.5, kernel=poly;, score=0.832 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=0.5, kernel=poly;, score=0.895 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=0.5, kernel=poly;, score=0.801 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=0.5, kernel=poly;, score=0.885 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=1, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=1, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=1, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=1, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=1, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=1, kernel=rbf;, score=0.884 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=1, kernel=rbf;, score=0.811 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=1, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=1, kernel=rbf;, score=0.809 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=1, kernel=rbf;, score=0.831 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=1, kernel=poly;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=1, kernel=poly;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=1, kernel=poly;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=1, kernel=poly;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=1, kernel=poly;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=5, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=5, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=5, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=5, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=5, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=5, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=5, kernel=rbf;, score=0.777 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=5, kernel=rbf;, score=0.892 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=5, kernel=rbf;, score=0.820 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=5, kernel=rbf;, score=0.808 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=5, kernel=poly;, score=0.897 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=5, kernel=poly;, score=0.837 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=5, kernel=poly;, score=0.898 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=5, kernel=poly;, score=0.806 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=5, kernel=poly;, score=0.886 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=10, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=10, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=10, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=10, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=10, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=10, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=10, kernel=rbf;, score=0.784 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=10, kernel=rbf;, score=0.882 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=10, kernel=rbf;, score=0.795 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=10, kernel=rbf;, score=0.813 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=10, kernel=poly;, score=0.900 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=10, kernel=poly;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=10, kernel=poly;, score=0.901 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=10, kernel=poly;, score=0.806 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=10, kernel=poly;, score=0.889 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=25, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=25, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=25, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=25, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=25, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=25, kernel=rbf;, score=0.881 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=25, kernel=rbf;, score=0.784 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=25, kernel=rbf;, score=0.886 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=25, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=25, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=25, kernel=poly;, score=0.897 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=25, kernel=poly;, score=0.839 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=25, kernel=poly;, score=0.900 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=25, kernel=poly;, score=0.807 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=25, kernel=poly;, score=0.894 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=50, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=50, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=50, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=50, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=50, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=50, kernel=rbf;, score=0.877 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=50, kernel=rbf;, score=0.778 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=50, kernel=rbf;, score=0.879 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=50, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=50, kernel=rbf;, score=0.809 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=50, kernel=poly;, score=0.900 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=50, kernel=poly;, score=0.837 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=50, kernel=poly;, score=0.900 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=50, kernel=poly;, score=0.808 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=50, kernel=poly;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=100, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=100, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=100, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=100, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=100, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=100, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=100, kernel=rbf;, score=0.773 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=100, kernel=rbf;, score=0.860 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=100, kernel=rbf;, score=0.792 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=100, kernel=rbf;, score=0.802 total time=   0.0s
# [CV 1/5] END C=0.1, degree=1, gamma=100, kernel=poly;, score=0.900 total time=   0.0s
# [CV 2/5] END C=0.1, degree=1, gamma=100, kernel=poly;, score=0.839 total time=   0.0s
# [CV 3/5] END C=0.1, degree=1, gamma=100, kernel=poly;, score=0.899 total time=   0.0s
# [CV 4/5] END C=0.1, degree=1, gamma=100, kernel=poly;, score=0.808 total time=   0.0s
# [CV 5/5] END C=0.1, degree=1, gamma=100, kernel=poly;, score=0.885 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.1, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.1, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.1, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.1, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.1, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.1, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.1, kernel=rbf;, score=0.846 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.1, kernel=rbf;, score=0.909 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.1, kernel=rbf;, score=0.810 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.1, kernel=rbf;, score=0.875 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.753 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.716 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.767 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.798 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.698 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.5, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.5, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.5, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.5, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.5, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.5, kernel=rbf;, score=0.868 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.5, kernel=rbf;, score=0.832 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.5, kernel=rbf;, score=0.910 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.5, kernel=rbf;, score=0.796 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.5, kernel=rbf;, score=0.851 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.5, kernel=poly;, score=0.864 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.5, kernel=poly;, score=0.832 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.5, kernel=poly;, score=0.908 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.5, kernel=poly;, score=0.777 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.5, kernel=poly;, score=0.801 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=1, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=1, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=1, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=1, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=1, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=1, kernel=rbf;, score=0.884 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=1, kernel=rbf;, score=0.811 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=1, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=1, kernel=rbf;, score=0.809 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=1, kernel=rbf;, score=0.831 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.866 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.825 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.786 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.791 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=5, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=5, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=5, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=5, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=5, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=5, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=5, kernel=rbf;, score=0.777 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=5, kernel=rbf;, score=0.892 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=5, kernel=rbf;, score=0.820 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=5, kernel=rbf;, score=0.808 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=5, kernel=poly;, score=0.859 total time=   0.1s
# [CV 2/5] END C=0.1, degree=2, gamma=5, kernel=poly;, score=0.814 total time=   0.1s
# [CV 3/5] END C=0.1, degree=2, gamma=5, kernel=poly;, score=0.898 total time=   0.1s
# [CV 4/5] END C=0.1, degree=2, gamma=5, kernel=poly;, score=0.804 total time=   0.1s
# [CV 5/5] END C=0.1, degree=2, gamma=5, kernel=poly;, score=0.799 total time=   0.2s
# [CV 1/5] END C=0.1, degree=2, gamma=10, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=10, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=10, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=10, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=10, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=10, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=10, kernel=rbf;, score=0.784 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=10, kernel=rbf;, score=0.882 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=10, kernel=rbf;, score=0.795 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=10, kernel=rbf;, score=0.813 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=10, kernel=poly;, score=0.864 total time=   0.4s
# [CV 2/5] END C=0.1, degree=2, gamma=10, kernel=poly;, score=0.819 total time=   0.4s
# [CV 3/5] END C=0.1, degree=2, gamma=10, kernel=poly;, score=0.898 total time=   0.5s
# [CV 4/5] END C=0.1, degree=2, gamma=10, kernel=poly;, score=0.795 total time=   0.5s
# [CV 5/5] END C=0.1, degree=2, gamma=10, kernel=poly;, score=0.803 total time=   0.5s
# [CV 1/5] END C=0.1, degree=2, gamma=25, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=25, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=25, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=25, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=25, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=25, kernel=rbf;, score=0.881 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=25, kernel=rbf;, score=0.784 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=25, kernel=rbf;, score=0.886 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=25, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=25, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=25, kernel=poly;, score=0.863 total time=   3.0s
# [CV 2/5] END C=0.1, degree=2, gamma=25, kernel=poly;, score=0.821 total time=   4.9s
# [CV 3/5] END C=0.1, degree=2, gamma=25, kernel=poly;, score=0.899 total time=   2.4s
# [CV 4/5] END C=0.1, degree=2, gamma=25, kernel=poly;, score=0.803 total time=   2.5s
# [CV 5/5] END C=0.1, degree=2, gamma=25, kernel=poly;, score=0.804 total time=   3.0s
# [CV 1/5] END C=0.1, degree=2, gamma=50, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=50, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=50, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=50, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=50, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=50, kernel=rbf;, score=0.877 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=50, kernel=rbf;, score=0.778 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=50, kernel=rbf;, score=0.879 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=50, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=50, kernel=rbf;, score=0.809 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=50, kernel=poly;, score=0.871 total time=  18.2s
# [CV 2/5] END C=0.1, degree=2, gamma=50, kernel=poly;, score=0.826 total time=  20.8s
# [CV 3/5] END C=0.1, degree=2, gamma=50, kernel=poly;, score=0.899 total time=  19.6s
# [CV 4/5] END C=0.1, degree=2, gamma=50, kernel=poly;, score=0.802 total time=  22.3s
# [CV 5/5] END C=0.1, degree=2, gamma=50, kernel=poly;, score=0.800 total time=  19.3s
# [CV 1/5] END C=0.1, degree=2, gamma=100, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=100, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=100, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=100, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=100, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=100, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=100, kernel=rbf;, score=0.773 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=100, kernel=rbf;, score=0.860 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=100, kernel=rbf;, score=0.792 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=100, kernel=rbf;, score=0.802 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=100, kernel=poly;, score=0.863 total time= 1.2min
# [CV 2/5] END C=0.1, degree=2, gamma=100, kernel=poly;, score=0.825 total time= 1.9min
# [CV 3/5] END C=0.1, degree=2, gamma=100, kernel=poly;, score=0.899 total time=  48.9s
# [CV 4/5] END C=0.1, degree=2, gamma=100, kernel=poly;, score=0.795 total time=  58.4s
# [CV 5/5] END C=0.1, degree=2, gamma=100, kernel=poly;, score=0.798 total time= 1.3min
# [CV 1/5] END C=0.1, degree=3, gamma=0.1, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.1, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.1, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.1, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.1, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=0.1, kernel=rbf;, score=0.883 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.1, kernel=rbf;, score=0.846 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.1, kernel=rbf;, score=0.909 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.1, kernel=rbf;, score=0.810 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.1, kernel=rbf;, score=0.875 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.910 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.852 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.898 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.868 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=0.5, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.5, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.5, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.5, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.5, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=0.5, kernel=rbf;, score=0.868 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.5, kernel=rbf;, score=0.832 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.5, kernel=rbf;, score=0.910 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.5, kernel=rbf;, score=0.796 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.5, kernel=rbf;, score=0.851 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=0.5, kernel=poly;, score=0.904 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.5, kernel=poly;, score=0.847 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.5, kernel=poly;, score=0.890 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.5, kernel=poly;, score=0.829 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.5, kernel=poly;, score=0.891 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=1, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=1, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=1, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=1, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=1, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=1, kernel=rbf;, score=0.884 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=1, kernel=rbf;, score=0.811 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=1, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=1, kernel=rbf;, score=0.809 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=1, kernel=rbf;, score=0.831 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.902 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.850 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.882 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.858 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.861 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=5, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=5, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=5, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=5, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=5, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=5, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=5, kernel=rbf;, score=0.777 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=5, kernel=rbf;, score=0.892 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=5, kernel=rbf;, score=0.820 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=5, kernel=rbf;, score=0.808 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=5, kernel=poly;, score=0.911 total time=   6.1s
# [CV 2/5] END C=0.1, degree=3, gamma=5, kernel=poly;, score=0.849 total time=   1.0s
# [CV 3/5] END C=0.1, degree=3, gamma=5, kernel=poly;, score=0.897 total time=   1.7s
# [CV 4/5] END C=0.1, degree=3, gamma=5, kernel=poly;, score=0.852 total time=   1.1s
# [CV 5/5] END C=0.1, degree=3, gamma=5, kernel=poly;, score=0.858 total time=   4.7s
# [CV 1/5] END C=0.1, degree=3, gamma=10, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=10, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=10, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=10, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=10, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=10, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=10, kernel=rbf;, score=0.784 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=10, kernel=rbf;, score=0.882 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=10, kernel=rbf;, score=0.795 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=10, kernel=rbf;, score=0.813 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=10, kernel=poly;, score=0.911 total time= 1.4min
# [CV 2/5] END C=0.1, degree=3, gamma=10, kernel=poly;, score=0.851 total time=  15.2s
# [CV 3/5] END C=0.1, degree=3, gamma=10, kernel=poly;, score=0.896 total time=  12.9s
# [CV 4/5] END C=0.1, degree=3, gamma=10, kernel=poly;, score=0.843 total time=  31.4s
# [CV 5/5] END C=0.1, degree=3, gamma=10, kernel=poly;, score=0.862 total time=  20.1s
# [CV 1/5] END C=0.1, degree=3, gamma=25, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=25, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=25, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=25, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=25, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=25, kernel=rbf;, score=0.881 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=25, kernel=rbf;, score=0.784 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=25, kernel=rbf;, score=0.886 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=25, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=25, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=25, kernel=poly;, score=0.900 total time= 5.9min
# [CV 2/5] END C=0.1, degree=3, gamma=25, kernel=poly;, score=0.853 total time=10.7min
# [CV 3/5] END C=0.1, degree=3, gamma=25, kernel=poly;, score=0.894 total time= 7.0min
# [CV 4/5] END C=0.1, degree=3, gamma=25, kernel=poly;, score=0.837 total time= 9.3min
# [CV 5/5] END C=0.1, degree=3, gamma=25, kernel=poly;, score=0.846 total time= 7.0min
# [CV 1/5] END C=0.1, degree=3, gamma=50, kernel=linear;, score=0.895 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=50, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=50, kernel=linear;, score=0.897 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=50, kernel=linear;, score=0.802 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=50, kernel=linear;, score=0.888 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=50, kernel=rbf;, score=0.877 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=50, kernel=rbf;, score=0.778 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=50, kernel=rbf;, score=0.879 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=50, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=50, kernel=rbf;, score=0.809 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=50, kernel=poly;, score=0.877 total time=62.8min

# %%
print('\n All results:')
print(random_search.cv_results_)
print('\n Best estimator:')
print(random_search.best_estimator_)
#print('\n Best normalized gini score for %d-fold search with %d parameter combinations:' % (folds, param_comb))
#print(random_search.best_score_ * 2 - 1)
print('\n Best hyperparameters:')
print(random_search.best_params_)
#results = pd.DataFrame(random_search.cv_results_)
#results.to_csv('xgb-random-grid-search-results-01.csv', index=False)

# %% [markdown]
# ## GradientBoosting

# %%
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
data_df = pd.concat([train_df, test_df])

aplying_preprocesing(data_df, train_df, test_df)

X = train_df.drop('Survived', axis=1)
y = train_df['Survived']

std_scaler = StandardScaler()
X = std_scaler.fit_transform(X)

# %%
parameters = {
'min_samples_split' : [2, 5, 10, 25, 50, 100],
'max_depth' : [5,10,15,20,25,50],
'learning_rate' : [0.1, 0.01, 0.05, 0.025,0.3],
'n_estimators' : [25, 50,100, 250, 500, 1000, 2500],
'subsample' : [0.7, 0.75,0.8,0.85],
'min_samples_leaf' : [1, 5, 10, 25, 50, 100, 250]
}

# %%
folds = 5
param_comb = 5000

kf = KFold(n_splits = folds, shuffle = True, random_state = 42)
svc = GradientBoostingClassifier()
random_search = RandomizedSearchCV(svc, param_distributions=parameters, scoring='roc_auc', cv = kf.split(X, y), verbose = 3, n_iter=param_comb)

start_time = timer(None) 
random_search.fit(X, y)
timer(start_time)

# %%
print('\n All results:')
print(random_search.cv_results_)
print('\n Best estimator:')
print(random_search.best_estimator_)
#print('\n Best normalized gini score for %d-fold search with %d parameter combinations:' % (folds, param_comb))
#print(random_search.best_score_ * 2 - 1)
print('\n Best hyperparameters:')
print(random_search.best_params_)
#results = pd.DataFrame(random_search.cv_results_)
#results.to_csv('xgb-random-grid-search-results-01.csv', index=False)

# %% [markdown]
# ## MLP

# %%
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
data_df = pd.concat([train_df, test_df])

aplying_preprocesing(data_df, train_df, test_df)

X = train_df.drop('Survived', axis=1)
y = train_df['Survived']

std_scaler = StandardScaler()
X = std_scaler.fit_transform(X)

# %%
parameters = {
'hidden_layer_sizes' : [(10,), (25,), (50,), (100), (250), (500,), (1000,)],
'activation' : ['identity','logistic','tanh','relu'],
'solver' : ['lbfgs', 'sgd', 'adam'],
'alpha' : [0.0001, 0.00001,0.000025,0.00005, 0.00025, 0.0005, 0.001],
'learning_rate' : ['constant', 'invscaling', 'adaptive'],
'min_samples_leaf' : [1, 5, 10, 25, 50, 100, 250],
}

# %%
folds = 5
param_comb = 5000

kf = KFold(n_splits = folds, shuffle = True, random_state = 42)
svc = MLPClassifier(max_iter=1500)
random_search = RandomizedSearchCV(svc, param_distributions=parameters, scoring='roc_auc', cv = kf.split(X, y), verbose = 3, n_iter=param_comb)

start_time = timer(None) 
random_search.fit(X, y)
timer(start_time)

# %%
print('\n All results:')
print(random_search.cv_results_)
print('\n Best estimator:')
print(random_search.best_estimator_)
#print('\n Best normalized gini score for %d-fold search with %d parameter combinations:' % (folds, param_comb))
#print(random_search.best_score_ * 2 - 1)
print('\n Best hyperparameters:')
print(random_search.best_params_)
#results = pd.DataFrame(random_search.cv_results_)
#results.to_csv('xgb-random-grid-search-results-01.csv', index=False)
